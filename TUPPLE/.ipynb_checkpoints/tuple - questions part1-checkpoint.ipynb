# %%
#1
a=(1,2,3,4,5,6)
print(a)
print(type(a))
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>

# %%
#2
a=("disha")
print(len(a))
print(a[0])
print(a[2])
print(a[4])
# Out:
# 5
# d
# s
# a

# %%
#3
a=(1,5,4,6,2,7,9)
number=int(input("enter number"))
for i in number:
    if i in a:
        print
