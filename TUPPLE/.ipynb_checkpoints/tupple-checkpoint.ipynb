# %%
a=(10,)
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=(10)
print(type(a))
# Out:
# <class 'int'>

# %%
#changing list to tuple (TYPE CASTING)
b=[10,20,30]
print(type(b))
c=tuple(b)
print(type(c))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
t=(10,"gagan",10.5,[100,200])
print(t[0])
print(t[2])
t[2]="da"
print(t) #error becuase tuple is immutable
# Out:
# 10
# 10.5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 print(t[0])
#       3 print(t[2])
# ----> 4 t[2]="da"
#       5 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=(10,"gagan",10.5,[100,200],55,65)
print(t[1::])
print(t[:4:])
print(t[::2])
print(t[::-1])
# Out:
# ('gagan', 10.5, [100, 200], 55, 65)
# (10, 'gagan', 10.5, [100, 200])
# (10, 10.5, 55)
# (65, 55, [100, 200], 10.5, 'gagan', 10)
