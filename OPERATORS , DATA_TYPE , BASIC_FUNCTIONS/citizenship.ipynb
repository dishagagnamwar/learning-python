# %%
age=int(input("enter age"))
citizenship=input("enter citizenship")
if age>=18:
    if citizenship=="india":
        print ("eligible")
    else:
          print("indian citizenship required")
else:
    print("age should be >18")
# Out:
# enter age 7
# enter citizenship india
# age should be >18

# %%
age=int(input("enter age"))
citizenship=input("enter citizenship")
if age>=18 and citizenship=="indian":
    print("eligible")
else:
    print("not eligible")
# Out:
# enter age 45
# enter citizenship indian
# eligible
