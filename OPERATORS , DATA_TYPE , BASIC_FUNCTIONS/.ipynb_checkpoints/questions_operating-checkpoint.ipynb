# %%
#question1
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))

print("sum is :",num1+num2)
# Out:
# enter first number: 4
# enter second number: 5
# sum is : 9

# %%
#question2
price1=int(input("enter first number:"))
price2=int(input("enter second number:"))
price3=int(input("enter third number:"))
print("sum is:",price1+price2+price3)
# Out:
# enter first number: 56
# enter second number: 55
# enter third number: 66
# sum is: 177

# %%
#question 3 
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
print("difference is:",num1-num2)
# Out:
# enter first number: 58
# enter second number: 58
# difference is: 0

# %%
#question 4 
length=int(input("enter length:"))
width=int(input("enter width:"))
print("total area is :",length*width)
# Out:
# enter length: 59
# enter width: 68
# total area is : 4012

# %%
#question 5
# Average of Five Marks Explanation: Accept five subject marks and display the average. 
#Concepts: + and / operators
n1=int(input("enter 1st number:"))
n2=int(input("enter 2nd number:"))
n3=int(input("enter 3rd number:"))
n4=int(input("enter 4th number:"))
n5=int(input("enter 5th number:"))
print("average is:",(n1+n2+n3+n4+n5)/5)
# Out:
# enter 1st number: 59
# enter 2nd number: 3
# enter 3rd number: 34
# enter 4th number: 4
# enter 5th number: 8
# average is: 21.6

# %%
#question 6
#Quotient and Remainder Explanation: 
	#Accept two numbers and display both quotient and remainder. 
     #   Concepts: // and % operators

n1=int(input("enter dividend:"))
n2=int(input("enter divisor:"))
print("quotient is:",n1//n2)
print("remainder is :",n1%n2)
# Out:
# enter dividend: 1
# enter divisor: 2
# quotient is: 0
# remainder is : 1

# %%
#question 7
 #Square and Cube Explanation: 
	#Accept a number and display its square and cube.
	#Concepts: ** operator

n1=int(input("enter n1:"))
print("square is :",n1*n1)
print("cube is:",n1**3)
# Out:
# enter n1: 2
# square is : 4
# cube is: 8

# %%
#question 8
#Salary Increment Explanation: 
#	Accept an employee’s salary and increase it by 10%. 
#	Concepts: +, *, / operators

salary=int(input("enter salary:"))
print("increase by 10%:",salary+ salary*10/100)
# Out:
# enter salary: 5
# increase by 10%: 5.5

# %%
#question 9
#Temperature Conversion Explanation: 
#       Formula: (C * 9/5) + 32 
 #       Concepts: Arithmetic operators

temp=float(input("enter temp in celcius"))
print("temp in F :", (temp*9/5)+32)
# Out:
# enter temp in celcius 7
# temp in F : 44.6
