# %%
#numeric datatype 
#integer -infinity to +infinity , unindexed , immutable
#float -infinity to +infinity , continues number 
#type() it is used to check datatype of variable 
a=10 
print(type(a))

b=10.5
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
#string datatype  : chracter inside singal or double quote 
#single line :single quote ('') or double quote(" ")
#multiple line : ('''   ''') or ("""  """)

s1="gagan" 
s2= """
my 
name 
is 
gagan 
"""
print(s1)
print (s2)
# Out:
# gagan
#
# my
# name
# is
# gagan
