# %%
#operator 
#arithmatic operator 
a=10
b=3
print("addition :",a+b)
print("substraction:",a-b)
print("multiplication:",a*b)
print("division:",a/b)
print("floor division:",a//b)
print("exponant:",a**b)
# Out:
# addition : 13
# substraction: 7
# multiplication: 30
# division: 3.3333333333333335
# floor division: 3
# exponant: 1000

# %%
#assignment operator 
#it is used to assign value to v`ariable 
# =,+=,-=,*=,/=, %=, **=, //=

a=10
a+=15
print(a)

b=15
b-=10
print(b)

b*=5
print(b)

a=3
b/=4
print(b)

a=9
a
%=6 #remainer
print(b)

a=5
b**=10
print(b)

a=8
b//=3 #quotient
print(b)
# Out:
# 25
# 5
# 25
# 6.25
# 0.25
# 9.5367431640625e-07
# 0.0

# %%
#comparision operator 
# ==, != , <= , >= , > , < 

a=10
b=5
print(a==b)
print(a!=b)
print(a<=b)
print(a>=b)
print(a>b)
print(a<b)
# Out:
# False
# True
# False
# True
# True
# False

# %%
#bitwise operator 
#bin() it is used to find binary of any number 
a =5
b=3
print(f"binary of{a} is ", bin(b))
print(f"binary of{b} is ", bin(a))
print(a&b) #binary AND operation
print(a|b) #binary OR operation
print(a^b) #binary XOR operaton
print(~a) #~n=-(n+1) #binary not
# Out:
# binary of5 is  0b11
# binary of3 is  0b101
# 1
# 7
# 6
# -6

# %%
a=9
a%=6
print(a)

b=8
b//=3
print(b)
# Out:
# 3
# 2

# %%
a=9
a%=6
print(a)
# Out:
# 3
