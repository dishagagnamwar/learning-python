# %%
#nested for loop 
for i in range(2):
    for j in range(2):
        print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1

# %%
#check prime no 
number=int(input("enter no:"))
if number==0 or num==1:
    print("not a prime no")
else: 
    is_prime= True
    for i in range (2,number):
if number%i==0:
    is_prime= False 
        break
        if is_prime:
            print("prime")
        else:print("not prime")
# Out:
#   Cell In[7], line 8
#     if number%i==0:
#                    ^
# IndentationError: expected an indented block after 'for' statement on line 7
