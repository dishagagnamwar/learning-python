# %%
l=[2,7,11,15,]
target=9
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i]+l[j]==target:
            print([i],[j])
# Out:
# [0] [1]

# %%
l=[2,7,11,15,5,1,4]
target=9
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i]+l[j]==target:
            print([i],[j])
# Out:
# [0] [1]
# [4] [6]
