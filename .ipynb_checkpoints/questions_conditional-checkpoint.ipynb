# %%
#question1
number=int(input("enter a number:"))
if number>0:print("positive")
elif number==0 :print("zero")
else :print("negative")
# Out:
# enter a number: 8
# positive

# %%
#question 2
number=int(input("enter a number:"))
if number%2==0:print("even")
else :print("odd")
# Out:
# enter a number: 98
# even

# %%
#question =3
age=int(input("enter age :"))
if age>=18:
    print("eligible for vote")
else:
    print("not eligible for vote")
# Out:
# enter age : 12
# not eligible for vote

# %%
#question 4 LARGEST OF TWO NUMBERS
number1=int(input("enter a number"))
number2=int(input("enter a number"))
if number1>number2:print(number1)
else :print(number2)
# Out:
# enter a number 8
# enter a number 98
# 98

# %%
#question 5
number=int(input("enter a number:"))
if number%5==0:print("divisible by 5")
else :print("not divisible by 5")
# Out:
# enter a number: 8
# not divisible by 5

# %%
#question 6 
marks=int(input("enter marks:"))
if marks >=35:print("pass")
else :print("fail")
# Out:
# enter marks: 88
# pass

# %%
#question 8
character=input("enter a alphabet")
if character in "a,e,i,o,u":
    print("vowel")
else:print("consonent")
# Out:
# enter a alphabet H
# consonent

# %%
#question 9 
number=int(input("enter a number:"))
if number>0:print("positive")
elif number==0 :print("zero")
else :print("negative")
# Out:
# enter a number: 89
# positive

# %%
#question 10 
number=int(input("enter a number:"))
if number%3==0 and number%7==0:print("divisible by 3&7")
else :print("not divisible by 3&7")
# Out:
# enter a number: 89
# not divisible by 3&7

# %%
#question 11 
number1=int(input("enter no 1 :"))
number2=int(input("enter no 2:"))
number3=int(input("enter no 3:"))
if number1>number2 and number1>number3:
    print("number1 is greater")
elif number2>number1 and number2>number3:
    print("number2 is greater")
else:print("number3 is greater")
# Out:
# enter no 1 : 2
# enter no 2: 6
# enter no 3: 9
# number3 is greater

# %%
#question 12
#Grade Calculator ,Explanation:
#Assign grades based on marks.
#Concepts: - Multiple conditions
marks=int(input("enter marks:"))
if marks>=80: print("excellent:")
elif marks>=60: print("very good:")
else:print("average:")
# Out:
# enter marks: 95
# excellent:

# %%
#question 13
#leap year checker
year=int(input("enter year:"))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print("leap year")
        else:print("not leap year")
    else:print("leap year")
else:print("not leap year")
# Out:
# enter year: 2024
# leap year

# %%
#question 14
#14. Electricity Bill Calculator
#Explanation:Calculate bill according to unit slabs.
#Concepts:- if...elif...else
per_unit=10
unit=int(input("enter units"))
if unit>1500:print("very much",unit*10)
elif unit>500:print("normal",unit*10)
else:print("very less",unit*10)
# Out:
# enter units 102
# very less 1020

# %%
#question 15
salary=int(input("enter salary:"))
if salary>50000:print("salary after bonus:",salary+salary*10/100)
else:print("salary after bonus:",salary+salary*5/100)
# Out:
# enter salary: 78000
# salary after bonus: 85800.0

# %%
#question 16
username=input("enter username:")
password=input("enter password:")
if username =="admin" and password=="admin123":
    print("valid")
else :print("invalid")
# Out:
# enter username: ghGASHG
# enter password: SK
# invalid

# %%
#question 17
#Simple Calculator
#explanation:Perform arithmetic operation based on user choice.
#Concepts:- if...elif...else
# Out:
# enter username: ghGASHG
# enter password: SK
# invalid

# %%
# question 18
a=int(input("enter side a:"))
b=int(input("enter side b:"))
c=int(input("enter side c:"))
if a==b and a==c and b==c:
    print("equilateral")
elif (a==b and a!=c) or (b==c and b!=a) or (a==c and a!=b):
    print("isosceles")
else:print("scelene")
# Out:
# enter side a: 7
# enter side b: 9
# enter side c: 5
# scelene

# %%
#question 19
balance=1500
withdrawal=int(input("enter amount:"))
if withdrawal>balance: print("allow:")
else:print("insufficient")
# Out:
# enter amount: 78000
# allow:

# %%
#question 20
#Student Scholarship :Explanation:
#Scholarship if marks >=85 and attendance >=75.
#Concepts: - and operator
marks=int(input("enter marks"))
attendance=input("enter attendance")
if marks>=85 and attendance>=75:
    print("eligible")
else:print("not eligible")
# Out:
# enter marks 86
# enter attendance 45
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 7
#       5 marks=int(input("enter marks"))
#       6 attendance=input("enter attendance")
# ----> 7 if marks>=85 and attendance>=75:
#       8     print("eligible")
#       9 else:print("not eligible")
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
unit=int(input("enter unnits:"))
if unit>0 and unit<100:
    bill=unit*8
    print(bill)
# Out:
# enter unnits: 50
# 400
