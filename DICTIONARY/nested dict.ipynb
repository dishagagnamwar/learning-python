# %%
#integer key 
a={10:"A",20:"B",30:"C"}
print(a)
# Out:
# {10: 'A', 20: 'B', 30: 'C'}

# %%
#NESTED DICTIONARY 
employees={
    101:{"name":"disha",
         "salary":50000,
         "designation":"da"},
    
    102:{"name":"rishi",
         "salary":50000,
         "designation":"da"},
    
    103:{"name":"yash",
         "salary":50000,
         "designation":"da"}}
print(employees)
# Out:
# {101: {'name': 'disha', 'salary': 50000, 'designation': 'da'}, 102: {'name': 'rishi', 'salary': 50000, 'designation': 'da'}, 103: {'name': 'yash', 'salary': 50000, 'designation': 'da'}}

# %%
# !git push origin main
# Out:
# To https://github.com/dishagagnamwar/learning-python.git
#    e25e5cc..e685bd7  main -> main
