# %%
#1
d={"name":"disha","age":25,"city":"bhopal"}
print(d)
# Out:
# {'name': 'disha', 'age': 25, 'city': 'bhopal'}

# %%
#2
d={"name":"disha","age":25,"city":"bhopal"}
print(d.get("name"))
# Out:
# disha

# %%
#3
d={"name":"disha","age":25,"city":"bhopal"}
d.update({"course":"da"})
print(d)
# Out:
# {'name': 'disha', 'age': 25, 'city': 'bhopal', 'course': 'da'}

# %%
#4
d={'name': 'disha', 'age': 25, 'city': 'bhopal', 'course': 'da'}
d.update({'age':24})
print(d)
# Out:
# {'name': 'disha', 'age': 24, 'city': 'bhopal', 'course': 'da'}

# %%
#5
d={'name': 'disha', 'age': 25, 'city': 'bhopal', 'course': 'da'}
d.pop('city')
print(d)
# Out:
# {'name': 'disha', 'age': 25, 'course': 'da'}

# %%
#6
d={'name': 'disha', 'age': 25, 'course': 'da'}
print(len(d))
# Out:
# 3

# %%
#7
d={'name': 'disha', 'age': 25, 'city': 'bhopal', 'course': 'da'}
print(d.keys())
# Out:
# dict_keys(['name', 'age', 'city', 'course'])

# %%
#8
d={'name': 'disha', 'age': 25, 'city': 'bhopal', 'course': 'da'}
print(d.values())
# Out:
# dict_values(['disha', 25, 'bhopal', 'da'])

# %%
#9
d={'name': 'disha', 'age': 25, 'city': 'bhopal', 'course': 'da'}
for i in d.items():
    print(i)
# Out:
# ('name', 'disha')
# ('age', 25)
# ('city', 'bhopal')
# ('course', 'da')

# %%
#10
d={'name': 'disha', 'age': 25, 'city': 'bhopal', 'course': 'da'}
for i in d.keys():
    print(i)
# Out:
# name
# age
# city
# course

# %%
#11
d={'name': 'disha', 'age': 25, 'city': 'bhopal', 'course': 'da'}
for i in d.get():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #11
#       2 d={'name': 'disha', 'age': 25, 'city': 'bhopal', 'course': 'da'}
# ----> 3 for i in d.get():
#       4     print(i)
#
# TypeError: get expected at least 1 argument, got 0
