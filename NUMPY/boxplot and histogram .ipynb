# %%
import numpy as np

# %%
l=[20,21,22,21,20,23,23,24,28,29,32,30,32,24,25,26,24,25,25,25,26,31,20,20,23,27,28,28,29,26]
age=np.array(l)
print(age)
# Out:
# [20 21 22 21 20 23 23 24 28 29 32 30 32 24 25 26 24 25 25 25 26 31 20 20
#  23 27 28 28 29 26]

# %%
np.mean(age)
# Out:
# np.float64(25.233333333333334)

# %%
np.median(age)
# Out:
# np.float64(25.0)

# %%
Q1=np.quantile(age,0.25)
Q1
# Out:
# np.float64(23.0)

# %%
Q2=np.quantile(age,0.50)
Q2
# Out:
# np.float64(25.0)

# %%
Q3=np.quantile(age,0.75)
Q3
# Out:
# np.float64(28.0)

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(5.0)

# %%
upper_fence=Q3+(1.5*IQR)
upper_fence
# Out:
# np.float64(35.5)

# %%
lower_fence=Q1-(1.5*IQR)
lower_fence
# Out:
# np.float64(15.5)

# %%
l=[]
for i in age:
    if i<lower_fence or i>upper_fence:
        l.append(i)
print(l)
# Out:
# []

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(age,color="orange")
plt.show()

# %%
sns.histplot(age,kde=True,color="purple")
plt.show()

# %%
l=[10,11,2,7,20,21,22,21,20,23,23,24,28,29,32,30,32,24,25,26,24,25,25,25,56,82,91,26,31,20,20,23,27,28,28,29,26]
age=np.array(l)
print(age)
# Out:
# [10 11  2  7 20 21 22 21 20 23 23 24 28 29 32 30 32 24 25 26 24 25 25 25
#  56 82 91 26 31 20 20 23 27 28 28 29 26]

# %%
np.mean(age)
# Out:
# np.float64(27.45945945945946)

# %%
np.median(age)
# Out:
# np.float64(25.0)

# %%
q1=np.quantile(age,0.50)
q1
# Out:
# np.float64(25.0)

# %%
q2=np.quantile(age,0.25)
q2
# Out:
# np.float64(21.0)

# %%
q3=np.quantile(age,0.75)
q3
# Out:
# np.float64(28.0)

# %%
IQR=q3-q1
IQR
# Out:
# np.float64(3.0)

# %%
upper_fence=q3+(1.5*IQR)
upper_fence
# Out:
# np.float64(32.5)

# %%
lower_fence=q1+(1.5*IQR)
lower_fence
# Out:
# np.float64(29.5)

# %%
l=[]
for i in age:
    if i<lower_fence or i>upper_fence:
        l.append(l)
print(len(l))
print(l)
# Out:
# 33
# [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]

# %%
import numpy as np

# %%
import seaborn as sns
im
