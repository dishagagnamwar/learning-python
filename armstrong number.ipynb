# %%
#armstrong number
number=int(input("enter number"))
s=0
temp=number
power_of_digit=len(str(number))
while temp!=0:
    digit=temp%10
    s=s+digit**power_of_digit
    temp=temp//10
    if s==number:
        print("armstrong number")
    else:
         print("not armstrong")
# Out:
# enter number 153
# not armstrong
# not armstrong
# armstrong number

# %%
number=int(input("enter number"))
s=0
temp=number
power=len(str(number))
while temp!=0:
    digit=temp%10
    s=s+digit**power
    temp//10
    if s==number:
        print("arm")
    else:print("not arm")

# %%
# !git add .
