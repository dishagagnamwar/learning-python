# %% [markdown]
# ## set
# #created using {}, it has coma seperated values
# #heterogenius
# #mutable , unordered , unindexed
# #duplicate values is not allowed
# #remove duplicate values from list using typecasting (by set())
# s={10,10.5,"disha"}
# print(type(s))
# print(s)

# %%
#we would remove the duplicate value using set() method 
#list to set 
a=[10,20,30,20,20,"disha","disha"]
print(set(a))
# Out:
# {10, 'disha', 20, 30}

# %%
#set to list 
a={10,20,30,20,20,"disha","disha"}
l=list(a)
print(l)
# Out:
# [10, 'disha', 20, 30]

# %%
#looping through set 
a={10,20,30,20,20,"disha","disha"}
for i in a:
    print(i)
# Out:
# 10
# disha
# 20
# 30

# %%
# !git push origin main
# Out:
# To https://github.com/dishagagnamwar/learning-python.git
#    8ccc8b7..c879bae  main -> main
