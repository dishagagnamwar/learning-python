# %%
#1
s={1,2,3,4,5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
#2
s={()}
print(type(s))
# Out:
# <class 'set'>

# %%
#3
s={1,2,3,4}
s.add(5)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
#4
s={1,2,3,4,5,6}
s.update({23,34})
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 34, 23}

# %%
#5
s={1,2,3,4,5,6}
s.remove(5)
print(s)
# Out:
# {1, 2, 3, 4, 6}

# %%
#6
s={1,2,3,4,5,6}
s.discard(7)
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#7
s={1,2,3,4,5,6}
s.pop()
print(s)
# Out:
# {2, 3, 4, 5, 6}

# %%
#8
s={1,2,3,4,5,6}
print(len(s))
# Out:
# 6

# %%
#9
s={1,2,3,4,5,6}
a=(4) in s
print(a)
# Out:
# True

# %%
#10
s={1,2,3,3,2,5,4,5,6}
print(set(s))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#11
a={1,2,3,4}
b={5,6,7,8}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
#12
a={1,2,3,4,5}
b={5,6,7,8}
print(a.intersection(b))
# Out:
# {5}

# %%
#13
a={1,2,3,4}
b={5,6,7,8}
print(a.difference(b))
# Out:
# {1, 2, 3, 4}

# %%
#14
a={1,2,3,4}
b={4,5,6,7,8}
s=a.symmetric_difference(b)
print(s)
# Out:
# {1, 2, 3, 5, 6, 7, 8}

# %%
#15
a={1,2,3,4}
b={5,6,7,8}
print(a.issubset(b))
# Out:
# False

# %%
#16
a={1,2,3,4}
b={5,6,7,8}
print(a.issuperset(b))
# Out:
# False

# %%
#17
a={1,2,3,4}
b={5,6,7,8}
print(a.isdisjoint(b))
# Out:
# True

# %%
#18
a="ddishaa"
s=set(a.split())
count=len(s)
print(count)
# Out:
# 1

# %%
#19
a={1,2,3,4}
b={4,5,6,7,8}
common=set(a) & set(b)
print(common)
# Out:
# {4}

# %%
#20
s={"disha","disha","rishi"}
a=set(s)
print(a)

b=list(a)
print(b)
# Out:
# {'rishi', 'disha'}
# ['rishi', 'disha']

# %%
# !git push origin main
# Out:
# To https://github.com/dishagagnamwar/learning-python.git
#    cf0964d..e2c4f64  main -> main
