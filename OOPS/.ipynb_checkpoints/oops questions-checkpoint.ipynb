# %%
#question 1 
class students:
    def __init__(self,name,age):
     self.name=name
     self.age=age

    def display(self):
        print("name is",self.name)
        print("age is",self.age)

s1=students("disha",25)
print(s1.name)
print(s1.age)
# Out:
# disha
# 25

# %%
#question 2
