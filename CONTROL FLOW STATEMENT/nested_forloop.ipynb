# %%
#nested for loop 
for i in range(2):
    for j in range(2):
        print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1

# %%
#check prime no 
number=int(input("enter no:"))
if number<=1:print("not a prime no")
else: for i in range (2,number):
    if number%i==0:
        is_prime=false
