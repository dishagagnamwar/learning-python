# %%
#1
def addition(a,b):
    result=a+b
    print(result)
    
addition(1,2)
# Out:
# 3

# %%
#2
def max(a,b):
    if a>b:
        return a 
    else:
        return b 

result=max(1,8)
print(result)
# Out:
# 8

# %%
#3
def max(a,b):
    if a>b:
        return a 
    else:
        return b 

result=max(1,max(2,8))
print(result)
# Out:
# 8

# %%
#4
def even_odd():
    number=int(input("enter a number"))
    if number%2==0:
        return "even"
    else:
        return "odd"

result=even_odd()
print(result)
# Out:
# enter a number 7
# odd

# %%
#5
def classify():
    number=int(input("enter a number"))
    if number>0:
        return "positive"
    elif number==0:
        return "zero"
    else:
        return "neg
