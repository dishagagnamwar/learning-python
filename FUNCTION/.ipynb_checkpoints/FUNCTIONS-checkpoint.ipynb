# %%
#FUNCTIONS - it is used to perform any specific task

# %%
#USE of functions-
#1. it increase reuseability 
#2. it increase modularity 
#3. maintainaibility 
#4. easy to debug

# %%
#TYPES 
#2 types 
#1. predefined 
#2. user defined 
     #2.1 normal function
     #2.2 recursive function
     #2.3 lambda function

# %%
# !git push origin main
# Out:
# To https://github.com/dishagagnamwar/learning-python.git
#    82e9d0b..cc368df  main -> main
