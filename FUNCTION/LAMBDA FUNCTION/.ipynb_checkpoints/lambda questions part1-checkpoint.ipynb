# %%
#1 double every number
a=[2,4,6,8]
double=map(lambda x:x*x,a)
print(list(double))
# Out:
# [4, 16, 36, 64]

# %%
#2 add 10 to every number 
a=[5,10,15,20]
add_10=map(lambda a:a+10,a)
print(list(add_10))
# Out:
# [15, 20, 25, 30]

# %%
#3 substract 5 to every number 
a=[5,10,15,20]
sub_5=map(lambda a:a-5,a)
print(list(sub_5))
# Out:
# [0, 5, 10, 15]

# %%
#4 multiply every number by 3
a=[2,4,6,8]
mul_3=map(lambda a:a*3,a)
print(list(mul_3))
# Out:
# [6, 12, 18, 24]

# %%
# !git push origin main
# Out:
# To https://github.com/dishagagnamwar/learning-python.git
#    619b40d..864bd11  main -> main
