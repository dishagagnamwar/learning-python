# %%
#LIST METHODS

#append() - to insert element in list 
l=[10,20,30]
print(l)
l.append(40)
print(l)
# Out:
# [10, 20, 30]
# [10, 20, 30, 40]

# %%
#extend method()- used to add multiple elements
l=[10,20,30]
l.extend((60,50))
print(l)
# Out:
# [10, 20, 30, 60, 50]

# %%
#adding 2 lists
a1=[10,20,30]
a2=[50,60]
a1.extend(a2)
print(a1)
# Out:
# [10, 20, 30, 50, 60]

# %%
#adding 2 lists (2nd method)
a1=[10,20,30]
a2=[50,60]
print(a1+a2)
# Out:
# [10, 20, 30, 50, 60]

# %%
#insert ()-when we want to add any element at any specific index position 
#syntax - my_list.insert(index_position, element)
b=[10,20,30]
print("original",b)
b.insert(1,22)
print("modified",b)
# Out:
# original [10, 20, 30]
# modified [10, 22, 20, 30]

# %%
#Remove 
#pop()- to remove element from the list 
#syntax- pop(index_position)
#if there is not given any index position then it will remove the last element of the list 
#pop remove and return element
c=[10,20,30,40,50,60]
r=c.pop(2)
print(c)
print(r)

c.pop()
print(c)
# Out:
# [10, 20, 40, 50, 60]
# 30
# [10, 20, 40, 50]

# %%
#remove()- it is used to remove particular element from list 
#syntax= my_list.remove(element)
#it will remove first occurance of element

d=[10,40,30,40,50,60]
d.remove(40)
print(d)
# Out:
# [10, 30, 40, 50, 60]

# %%
#clear method()- to delete all element of the list 
d=[10,40,30,40,50,60]
d.clear()
print(d)
# Out:
# []

# %%
#index method () - to find index position of any particular element 
d=[10,40,30,40,50,60]
print(d.index(40))
print(d.index(40,2))
# Out:
# 1
# 3

# %%
#count() - it is used to count the occurance of any particular element 
d=[10,40,30,40,50,60,75,60]
print(d.count(40))
print(d.count(75))
# Out:
# 2
# 1

# %%
#sort()- it is used to arrange list 
d=[10,40,30,40,50,60,75,60]
d.sort()
print(d)
d.sort(reverse=True)
print(d)
# Out:
# [10, 30, 40, 40, 50, 60, 60, 75]
# [75, 60, 60, 50, 40, 40, 30, 10]

# %%
#sorted - does not modify the list 
#sort - modify the list

# %%
#reverse ()- it is used to reverse list 
d=[10,40,30,40,50,60,75,60]
r=d.reverse()
print(d)
# Out:
# [60, 75, 60, 50, 40, 30, 40, 10]

# %%
#copy ()- to make copy of list 
d=[10,20,30,50]
e=d.copy()
print(d)
# Out:
# [10, 20, 30, 50]

# %%
# !git push origin main
# Out:
# To https://github.com/dishagagnamwar/learning-python.git
#    deb5c58..c3055d5  main -> main
