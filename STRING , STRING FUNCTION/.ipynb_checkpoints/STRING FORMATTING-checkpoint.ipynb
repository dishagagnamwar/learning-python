# %%
#STRING FORMATING 
name="Gagan"
age=32
print("name is",name, "and age is",age)     #normal method
print(f"name is {name} and age is {age}")    #f-string method
print("name is {} and age is {}".format(name,age))    #.format method
# Out:
# name is Gagan and age is 32
# name is Gagan and age is 32
# name is Gagan and age is 32

# %%
# !git push origin main
# Out:
# To https://github.com/dishagagnamwar/learning-python.git
#    046d6df..c5fc99a  main -> main
