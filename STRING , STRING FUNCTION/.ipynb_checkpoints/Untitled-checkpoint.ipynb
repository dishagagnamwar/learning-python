# %%
#11
sentence=input("enter words or sentence")
s=sentence.replace("bad","***")
print(s)
# Out:
# enter words or sentence she is a bad girl
# she is a *** girl

# %%
#12
sentence=input("enter sentence")
s=sentence.split(" ")
a=" ".join(s)
print(a)
# Out:
# enter sentence python    is awesome
# python    is awesome

# %%
#13
filename=input("enter file name")
filename=filename.split(".")
print(filename[1])
# Out:
# enter file name report.pdf
# pdf

# %%
#14 check palindrome
#madam, level, mom , radar
s=input("enter string")
rev=""
for i in s:
    rev=i+rev
if s==rev:
     print("palindrome string")
else:
   print("not palindrome string")
# Out:
# enter string mom
# palindrome string

# %%
#14 check palindrome
#madam, level, mom , radar
s=input("enter string")
if s==s[::-1]:
     print("palindrome string")
else:
   print("not palindrome string")
# Out:
# enter string mom
# palindrome string

# %%
#15
name=input("enter a name")
character=input("enter a character")
count=name.count(character)
print("character count is",count)
# Out:
# enter a name banana
# enter a character a
# character count is 3

# %%
#16
email=input("enter email")
domain=email.split("@")
# Out:
# enter email rahulsharma@gmail.com
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       2 email=input("enter email")
#       3 domain=email.split("@")
# ----> 4 maskedemail="***@"+domain
#       5 print(maskedemail)
#
# TypeError: can only concatenate str (not "list") to str

# %%
#17
url=input("enter url")
url=url.split("http://")
if url:
    print("secure website")
else:print("not secure website")
# Out:
# enter url http://disha
# secure website

# %%
#18 word exists or not in that sentence
s=input("enter sentence")
word=input("enter word")

if word in s:
    print("word exists")
else:print("word do not exists")
# Out:
# enter sentence disha
# enter word m
# word do not exists

# %%
#19
name=input("enter name")
print(name.title())
# Out:
# enter name rahul sharma
# Rahul Sharma

# %%
#20
s=input("enter a setence")

total_characters=len(s)
print(total_characters)

total_words=len(s.split(" "))
print(total_words)

vowels=["a","e","i","o","u"]
for i in s:
    if i in vowels:
        print("
# Out:
# enter a setence disha gagnamwar
# 15
# 2
