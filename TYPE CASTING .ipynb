# %%
#type casting (changing variables datatype ) , (are of two types )
#implicit : can be changed during run type 
a=10 
b=12.5
c=a+b
print(c)
# Out:
# 22.5

# %%
a=1
b=True
c=a+b
print(c)
# Out:
# 2

# %%
#explicit (manually)
age=input("enter age:")
a=int(age)
print(type(a))
# Out:
# enter age: 10
# <class 'int'>

# %%
#type casting 
#any other form to integer
#any integer to any form 

a="123"
b=10.5 #float value 
print(int(b))

c=10
print(float(c))       #integer to float
print(type(str(c)))  #integer to str 
print(list(c))       #error because integer is immutable
# Out:
# 10
# 10.0
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 12
#      10 print(float(c))       #integer to float
#      11 print(type(str(c)))  #integer to str
# ---> 12 print(list(c))       #because integer is immutable
#
# TypeError: 'int' object is not iterable

# %%
#tuple  to list 
a=[10,"gagan",10.5]
t=tuple(a)
print(t)
print(type(t))

a=list(a)
print(a)
print(type(a))
# Out:
# (10, 'gagan', 10.5)
# <class 'tuple'>
# [10, 'gagan', 10.5]
# <class 'list'>

# %%
a=[10,10,20,25.5,"gagan","Gagan"]
S=set(a)
print(S)
print(type(S))
# Out:
# {'gagan', 10, 'Gagan', 20, 25.5}
# <class 'set'>

# %%
# !git push origin main
# Out:
# To https://github.com/dishagagnamwar/learning-python.git
#    be3a8ce..046d6df  main -> main
