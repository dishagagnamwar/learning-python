# %%
#method 1
a=10
b=20
print(f"{a} and {b}")

a=a+b
b=a-b
a=a-b
print(f"{a} and {b}")
# Out:
# 10 and 20
# 20 and 10

# %%
#method 2 without using third variable 
a=10
b=20
print(f"{a} and {b}")
a,b=b,a
print(f"{a} and {b}")
# Out:
# 10 and 20
# 20 and 10

# %%
#method 3 by using third variable
a=10
b=20
print(f"{a} and {b}")
c=a
a=b
b=a
print(f"{a} and {b}")
# Out:
# 10 and 20
# 20 and 20
